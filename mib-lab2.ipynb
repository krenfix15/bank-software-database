# %% [markdown]
# <a href="https://colab.research.google.com/github/krenfix15/bank-software-database/blob/main/mib-lab2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Laborator 2.
#
# Algoritmii metaeuristici sunt algoritmi de optimizare care utilizează heuristici pentru a explora spațiul soluțiilor și a găsi soluții bune sau aproape optime pentru problemele de optimizare. Acești algoritmi sunt concepuți să optimizeze procesul de optimizare, adică să găsească soluții bune într-un timp rezonabil, prin utilizarea principiilor de căutare heuristice, adaptarea procesului de căutare prin modificarea parametrilor de control, explorarea aleatorie a spațiului de soluții și utilizarea unor mecanisme de decizie care permit algoritmului să evite soluțiile neoptime.
#
# Acești algoritmi sunt utilizati pentru a rezolva probleme de optimizare care sunt dificil de rezolvat prin metode clasice de optimizare, precum programarea [liniară](http://gheorghe-grigoras.ieeia.tuiasi.ro/SDOE/5_Programarea%20LINIARA.pdf), convexă sau [neliniară](http://gheorghe-grigoras.ieeia.tuiasi.ro/SDOE/6_Programarea%20NELINIARA.pdf), cun ar fi unele probleme de optimizare complexe care implică multe variabile și constrângeri în domenii variate, precum inginerie, finanțe, medicină, transport și logistică, planificare și programare. Algoritmii metaeuristici sunt capabili să găsească soluții bune și pentru problemele care implică incertitudine sau variabilitate, ceea ce face ca acești algoritmi să fie foarte utili în domeniile în care este nevoie de optimizare în timp real.
#
# În general, motivul pentru utilizarea algoritmilor metaeuristici este acela că acești algoritmi sunt capabili să găsească soluții bune sau aproape optime pentru probleme complexe de optimizare într-un timp rezonabil, ceea ce face ca acești algoritmi să fie foarte utili în multe domenii diferite.
#
# ## Explorarea și exploatarea
#
# Explorarea și exploatarea sunt două concepte importante în contextul algoritmilor metaeuristici.
#
# Explorarea se referă la căutarea în întregul spațiu de soluții în căutarea unor soluții noi sau inedite. Aceasta implică o căutare mai aleatorie și mai largă a spațiului de soluții, adesea prin încercarea unor noi combinații de soluții și explorarea unor părți mai puțin frecvente ale spațiului de soluții. În general, explorarea este mai importantă la începutul procesului de optimizare, atunci când algoritmul încearcă să identifice soluții potențial bune.
#
# Exploatarea se referă la folosirea soluțiilor existente și găsite anterior pentru a găsi soluții mai bune sau optime. Aceasta implică o căutare mai concentrată și mai intensivă a spațiului de soluții, cu o atenție mai mare acordată soluțiilor care s-au dovedit a fi bune sau aproape optime. În general, exploatarea este mai importantă pe măsură ce procesul de optimizare continuă, deoarece algoritmul se concentrează asupra îmbunătățirii soluțiilor găsite anterior.
#
# Pentru a găsi soluții bune sau aproape optime, algoritmii metaeuristici trebuie să echilibreze explorarea și exploatarea. O strategie eficientă de căutare implică o exploatare intensivă în primele etape ale procesului de optimizare, urmată de o combinație echilibrată de exploatare și explorare pe măsură ce procesul continuă.
#
#
# ## Exemplu
#
# Optimizarea bazată pe gradient presupune că putem calcula prima (sau chiar a doua) derivată a funcției obiectiv. În multe cazuri funcțiile nu sunt diferențiabile în orice punct, sau sunt puternic multimodale, perturbate de zgomot etc.
#
# Chiar și în cazuri în care dispunem de gradient și abordăm o funcție simplă 1D, aceste metode se pot împotmoli în cel mai apropiat optim local. De exemplu, funcția $$ f(x) = x^4 + 5x^3 + 4x^2 - 4x + 1$$ are doar două minime locale, în $x=0.31$ și $x=-2.96$, cel din urmă fiind și minimul global. Totuși, metoda standard [`scipy.optimize.minimize_scalar`](https://docs.scipy.org/doc/scipy/reference/generated/scipy.optimize.minimize_scalar.html) de cele mai multe ori nu va găsi minimul global. Acest fapt se poate verifica empiric, rulând in repetate rânduri următoarea celulă cod.

# %%
from scipy.optimize import minimize_scalar
import matplotlib.pyplot as plt
import numpy as np

def plot_function(fun, lb=-10, ub=10, resolution=100, show=True):
  x = np.linspace(lb, ub, resolution)
  y = np.zeros(len(x))

  for i in range(len(x)):
    y[i] = fun(x[i])
   

  # setting the axes at the centre
  fig = plt.figure(figsize=(12, 8))
  ax = fig.add_subplot(1, 1, 1)
  ax.spines['left'].set_position('center')
  ax.spines['bottom'].set_position('zero')
  ax.spines['right'].set_color('none')
  ax.spines['top'].set_color('none')
  ax.xaxis.set_ticks_position('bottom')
  ax.yaxis.set_ticks_position('left')

  plt.plot(x, y, 'k')

  if show:
    plt.show()

def optimize_and_plot(fun, lb=-10, ub=10, method=minimize_scalar):
  # minime function
  res = method(fun)

  print(f'Minim localizat in punctul x={res.x}')

  plot_function(fun, lb, ub, show=False)

  plt.plot(res.x, res.fun, marker="o", markersize=25, markeredgecolor="blue", markerfacecolor="red", alpha = 0.6)
  plt.show()


def f1(x):
  return x ** 4 + 5 * x ** 3 + 4 * x ** 2 - 4 * x + 1

optimize_and_plot(f1, -4, 1)
# Out:
# Minim localizat in punctul x=0.3077914272615743

# %% [markdown]
# Situația este doar înrăutățită dacă funcția este perturbată de un zgomot semnificativ, gradientul numeric calculat în fiecare pas fiind incorect.

# %%
def f1_noisy(x):
    # additive gaussian noise 
    return f1(x) + np.random.normal(0, 1)

optimize_and_plot(f1_noisy, -4, 1)
# Out:
# Minim localizat in punctul x=0.3834919121905813

# %% [markdown]
# Iar aceste metode prin definiție sunt neadecvate pentru funcții nediferențiabile în unele regiuni.

# %%
def f1_picewise_non_diff(x):
  if x < -1.62 or x > -0:
    return f1(x) 
  
  return 4

optimize_and_plot(f1_picewise_non_diff, -4, 1)
# Out:
# Minim localizat in punctul x=-1.6180339754913822

# %% [markdown]
# Pe lângă toate aceste impedimente, pentru foarte multe cazuri și probleme reale, nu cunoaștem sau dispunem nici măcar de descrierea formală a funcției. De ex. în cazuri în care rezultatul este dat de o serie de măsurători sau simulări.
# În acest scenariu de ["cutie neagră"](https://www.lix.polytechnique.fr/~dambrosio/blackbox_material/Cassioli_1.pdf) dispunem doar de o modalitate de a crea sau modifica intrările $x_1 \dots x_d$ pentru funcția necunoscută, și de a observa rezultatul $y$ și "calitatea" acestuia, descris de o [funcție obiectiv](https://en.wikipedia.org/wiki/Loss_function) (denumit și fitness, funcție cost, energie etc.) $objFunc(y)$.
#
# ![](https://www.researchgate.net/profile/Nacim_Belkhir/publication/322035981/figure/fig1/AS:574906124910592@1514079709331/black-box-Optimization.png)
#
# Fig. 1. Optimizare black-box.
#
# # Căutare locală, metode traiectorie
#
# [Căutare locală](https://en.wikipedia.org/wiki/Local_search_(optimization)) are ca scop găsirea soluției optime (ce minimizează sau maximizează funcția obiectiv) în [vecinătatea](https://en.wikipedia.org/wiki/Neighbourhood_(mathematics)) unei soluții inițiale $x$.
#
# Algoritmii de căutare locală se deplasează de la soluție la soluție în spațiul soluțiilor posibile (spațiul de căutare) prin aplicarea repetată a unor perturbări, modificări locale. Astfel, pe parcursul rulării, acești algoritmi descriu o "traiectorie" în spațiul de căutare.
#
# ## Random Search
#
# Aceste [metode](https://en.wikipedia.org/wiki/Random_search) generează aleatoriu soluții din spațiul de căutare, și returnează aceea care obține evaluarea cea mai bună (conform fucției obiectiv).
#
# ```
# t = 0;
# result = createNewSolution();
# evaluate(result);
# while notFinished(t) do
#     a = createNewSolution();
#     evaluate(a);
#     if a isBetterThan result then
#       result = a;
#     t = t+1;
# end_while
# ```

# %% [markdown]
# Iată o exemplificare a metodei pe funcțiile mai sus definite.

# %%
from locale import resetlocale

class res_struct:
    x = 0.0
    fun = 0.0

def random_search(fun, lb=-10, ub=10, num_tries=10000):
  best_x = np.random.uniform(lb, ub)
  best_fval = fun(best_x)

  for i in range(num_tries):
    x = np.random.uniform(lb, ub)
    x_fval = fun(x)

    if x_fval < best_fval:
      best_fval = x_fval
      best_x = x
  
  res = res_struct()
  res.x = best_x
  res.fun = best_fval

  return res

mw = lambda x : random_search(x, -4, 1)

optimize_and_plot(f1, -4, 1, method=mw)
optimize_and_plot(f1_noisy, -4, 1, method=mw)
optimize_and_plot(f1_picewise_non_diff, -4, 1, method=mw)
# Out:
# Minim localizat in punctul x=-2.960719618702166
# Minim localizat in punctul x=-2.7873397844062513
# Minim localizat in punctul x=-2.960800330063317

# %% [markdown]
# Deși metoda are succes pe aceste funcții simple, ea nu este scalabilă. Odată cu creșterea numărului dimensiunilor și a intervalelor de definiție, probabilitatea localizării optimului global prin eșantionare uniformă aleatorie descrește exponențial.

# %% [markdown]
# ## Hill Climbing / Hill Descending
# Este o familie de metode iterative ce realizează o căutare locală,
# denumită și Îmbunătățire iterativă ([Iterative Improvement](https://www.ocf.berkeley.edu/~shidi/cs61a/wiki/Iterative_improvement#:~:text=Iterative%20improvement%20is%20a%20technique,%3D%20update(guess)%20return%20guess)). Metoda printr-un operator de perturbație, modificare aleatorie actualizează-îmbunătățește o soluție inițială, până când ajungem la soluția optimă (sau bugetul de timp alocat calculului, numărul maxim de încercări prestabilite este depășit).
#
# ```
# t = 0;
# result = createNewSolution();
# evaluate(result);
# while notFinished(t) do
#     a = clone(result);
#     mutate(a);
#     evaluate(a);
#     if a isBetterThan result then
#       result = a;
#    t = t+1;
# end_while
# ```
#
#
# Deseori se utilizează varianta iterată (Iterated Hill Climbing), în care algoritmul este repornit cu o soluție inițială nouă, pentru a mări gradul de explorare a spațiului de căutare.

# %%
def random_perturbation_hd(fun, lb=-10, ub=10, num_tries=10000, perturbation_magnitude=1):
  best_x = np.random.uniform(lb, ub)
  best_fval = fun(best_x)

  for i in range(num_tries):
    # local perturbation
    x = best_x + np.random.normal(0, perturbation_magnitude)
    x_fval = fun(x)

    if x_fval < best_fval:
      best_fval = x_fval
      best_x = x
  
  res = res_struct()
  res.x = best_x
  res.fun = best_fval

  return res

mw = lambda x : random_perturbation_hd(x, -4, 1)

optimize_and_plot(f1, -4, 1, method=mw)
optimize_and_plot(f1_noisy, -4, 1, method=mw)
optimize_and_plot(f1_picewise_non_diff, -4, 1, method=mw)
# Out:
# Minim localizat in punctul x=-2.9600614815272497
# Minim localizat in punctul x=-2.9252460652658656
# Minim localizat in punctul x=-2.9601283510604017

# %% [markdown]
# Principala provocare la folosirea acestor metode constă în buna alegere a parametrizării, în acest caz a operatorului de perturbație. De exemplu, cu o perturbație foarte mică scade puterea de explorare a metodei, iar rezultatele obișnuite nu mai sunt la fel de stabile (rulați următoarea celulă cod în mod repetat).

# %%
mw = lambda x : random_perturbation_hd(x, -4, 1, perturbation_magnitude=0.01)

optimize_and_plot(f1, -4, 1, method=mw)
optimize_and_plot(f1_noisy, -4, 1, method=mw)
optimize_and_plot(f1_picewise_non_diff, -4, 1, method=mw)
# Out:
# Minim localizat in punctul x=-2.960273931360239
# Minim localizat in punctul x=-1.57322521710436
# Minim localizat in punctul x=-1.5279868019340896

# %% [markdown]
# # Exerciții

# %% [markdown]
# ## Exercițiul 1
# Vom aborda o problemă cu funcție obiectiv discretă. Vom încerca să ghicim o parolă (secvență de caractere presupus necunoscută) cu aceste metode, având la dispoziție o funcție care ne indică câte caractere din șirul presupus se potrivesc cu parola (dar nu și poziția acestora).

# %%
import random
import numpy as np
import datetime
import matplotlib.pyplot as plt

# %%
random.seed(2001)

# %%
alphabet = 'abcdefghijklmnopqrstuvwxyz0123456789'
target = 'mib2023'
target_length = len(target)

# %% [markdown]
# Avem nevoie de o metodă care să genereze aleatoriu dint-un alfabet, un șir de caractere de lungine specificată.

# %%
def generateRandomSolution(length, alphabet):
    # TO DO sol = randomly choose length characters from alphabet
    sol = random.choices(alphabet, k=length)
    return ''.join(sol)

# %% [markdown]
# Testarea funcției.

# %%
# generate random solutions of increasing lengths
for i in range(2,10):
  print(generateRandomSolution(i, alphabet))
# Out:
# vn
# bx8
# vu0w
# wjfxd
# 7pxmn7
# qjzqiwe
# 24fh7k2x
# lyal390m7

# %% [markdown]
# Funcția obiectiv va specifica pentru o solțtie propusă, câte caractere se potrivesc, sunt la locul lor.

# %%
def objFuncNumMatches(guess): # objective function, also called, fitness, energy etc.
    # TO DO return the number of matches between guess and target
    no_matches = 0
    for i in range(len(guess)):
        if guess[i] == target[i]:
            no_matches += 1
    return no_matches

# %% [markdown]
# Testarea funcției obiectiv.

# %%
objFuncNumMatches(target)
# Out:
# 7

# %%
# generate random solutions and calculate their "fitness" (objective function value that we are maximizing)
for i in range(0,100):
  ind = generateRandomSolution(target_length, alphabet)
  fitness = objFuncNumMatches(ind)
  print('Solutia {0} are fitness-ul de: {1}'.format(ind, fitness))
# Out:
# Solutia onprh9d are fitness-ul de: 0
# Solutia wy96b3o are fitness-ul de: 0
# Solutia asgzuxv are fitness-ul de: 0
# Solutia sbiajdq are fitness-ul de: 0
# Solutia grt1udg are fitness-ul de: 0
# Solutia osqb3g9 are fitness-ul de: 0
# Solutia 8pf2q8j are fitness-ul de: 1
# Solutia 9nhwugd are fitness-ul de: 0
# Solutia t0e0iyd are fitness-ul de: 0
# Solutia 3c9dr3f are fitness-ul de: 0
# Solutia gqd6pvl are fitness-ul de: 0
# Solutia plg6noy are fitness-ul de: 0
# Solutia cpqr208 are fitness-ul de: 0
# Solutia zyzvspp are fitness-ul de: 0
# Solutia ph0lt81 are fitness-ul de: 0
# Solutia n3vquyr are fitness-ul de: 0
# Solutia 1gkcfcz are fitness-ul de: 0
# Solutia vwinnu9 are fitness-ul de: 0
# Solutia pqer5c4 are fitness-ul de: 0
# Solutia sf727xv are fitness-ul de: 1
# Solutia vsd9jz8 are fitness-ul de: 0
# Solutia 6d8o6nr are fitness-ul de: 0
# Solutia 9m0f6ic are fitness-ul de: 0
# Solutia y8c4cod are fitness-ul de: 0
# Solutia fdfsaqb are fitness-ul de: 0
# Solutia ai32nox are fitness-ul de: 2
# Solutia c0s7e50 are fitness-ul de: 0
# Solutia q0j4tsp are fitness-ul de: 0
# Solutia 7d9kgpw are fitness-ul de: 0
# Solutia gljwijt are fitness-ul de: 0
# Solutia oxag15t are fitness-ul de: 0
# Solutia pfia7mq are fitness-ul de: 0
# Solutia jafax7x are fitness-ul de: 0
# Solutia zl22ikg are fitness-ul de: 1
# Solutia voybfgg are fitness-ul de: 0
# Solutia 79mxzwf are fitness-ul de: 0
# Solutia tatr6pv are fitness-ul de: 0
# Solutia 0vuxsla are fitness-ul de: 0
# Solutia wfryjg8 are fitness-ul de: 0
# Solutia 1htql6v are fitness-ul de: 0
# Solutia zkq4na2 are fitness-ul de: 0
# Solutia 2hczout are fitness-ul de: 0
# Solutia jumihkf are fitness-ul de: 0
# Solutia 3j5tovu are fitness-ul de: 0
# Solutia ikhyc87 are fitness-ul de: 0
# Solutia kqs6tcp are fitness-ul de: 0
# Solutia dmh4t8a are fitness-ul de: 0
# Solutia 7wf7y9n are fitness-ul de: 0
# Solutia qnk52i8 are fitness-ul de: 0
# Solutia 3wvvqi2 are fitness-ul de: 0
# Solutia ci2fdou are fitness-ul de: 1
# Solutia 85hupbd are fitness-ul de: 0
# Solutia 6r6fdvm are fitness-ul de: 0
# Solutia 23euyu4 are fitness-ul de: 0
# Solutia n6ydofo are fitness-ul de: 0
# Solutia mfa0eii are fitness-ul de: 1
# Solutia d16hvwb are fitness-ul de: 0
# Solutia loyt6gg are fitness-ul de: 0
# Solutia 3cvipof are fitness-ul de: 0
# Solutia sq0cnoh are fitness-ul de: 0
# Solutia 2iaertq are fitness-ul de: 1
# Solutia ylifvbx are fitness-ul de: 0
# Solutia t1vdrnm are fitness-ul de: 0
# Solutia vv6jixf are fitness-ul de: 0
# Solutia 044039t are fitness-ul de: 0
# Solutia ocys6mv are fitness-ul de: 0
# Solutia i8atxfs are fitness-ul de: 0
# Solutia vfx6zkj are fitness-ul de: 0
# Solutia suwa5dc are fitness-ul de: 0
# Solutia 09f92b7 are fitness-ul de: 0
# Solutia r3urqwt are fitness-ul de: 0
# Solutia fu60w63 are fitness-ul de: 1
# Solutia xswtvz4 are fitness-ul de: 0
# Solutia ae4fcap are fitness-ul de: 0
# Solutia 2l3emub are fitness-ul de: 0
# Solutia 4t84kob are fitness-ul de: 0
# Solutia d1l5adu are fitness-ul de: 0
# Solutia q73yjls are fitness-ul de: 0
# Solutia 95b64ou are fitness-ul de: 1
# Solutia kqrdnlo are fitness-ul de: 0
# Solutia 2uoi2yk are fitness-ul de: 0
# Solutia srfglyt are fitness-ul de: 0
# Solutia 2xclkyt are fitness-ul de: 0
# Solutia uo0jpe3 are fitness-ul de: 1
# Solutia ned7sjq are fitness-ul de: 0
# Solutia tj3p2v2 are fitness-ul de: 0
# Solutia a9zeils are fitness-ul de: 0
# Solutia umxbizl are fitness-ul de: 0
# Solutia 2vfkt88 are fitness-ul de: 0
# Solutia globyh3 are fitness-ul de: 1
# Solutia 6oic8dl are fitness-ul de: 0
# Solutia 5irwz7i are fitness-ul de: 1
# Solutia f974web are fitness-ul de: 0
# Solutia 6qejdgu are fitness-ul de: 0
# Solutia eqb6ybf are fitness-ul de: 1
# Solutia cm4bbjp are fitness-ul de: 0
# Solutia a91dhkw are fitness-ul de: 0
# Solutia 3ijp8op are fitness-ul de: 1
# Solutia cnl2yme are fitness-ul de: 1
# Solutia r22cihj are fitness-ul de: 0

# %% [markdown]
# ### E1 a.
# Generați 10000000 de soluții și calculați calitatea acestora.
#
# - Care este timpul de rulare?
# - Care este distribuția valorilor de calitate?
# - Cât de des se potrivesc cel puțin 4 caractere?

# %% [markdown]
# ### Răspuns

# %%
hist = np.zeros(target_length)
startTime = datetime.datetime.now()

num_matches = 4

for i in range(10000000):
    randomSolution = generateRandomSolution(target_length, alphabet)
    fitness = objFuncNumMatches(randomSolution)
    hist[fitness] += 1
    if fitness >= num_matches:
        print('Solutia {0} are fitness-ul de: {1}'.format(randomSolution, fitness))

endTime = datetime.datetime.now()

print('Elapsed time: {0}'.format(str(endTime-startTime)))

print(hist)
plt.bar(range(0,target_length),hist)
plt.yscale('log')
# Out:
# Solutia mgb20ew are fitness-ul de: 4
# Solutia miqkg23 are fitness-ul de: 4
# Solutia mig102v are fitness-ul de: 4
# Solutia k5b20g3 are fitness-ul de: 4
# Solutia mikgk23 are fitness-ul de: 4
# Solutia y9b2w23 are fitness-ul de: 4
# Solutia mtb102c are fitness-ul de: 4
# Solutia mibp0po are fitness-ul de: 4
# Solutia 2ab0023 are fitness-ul de: 4
# Solutia 4ibx063 are fitness-ul de: 4
# Solutia ai62r23 are fitness-ul de: 4
# Solutia i3b2h23 are fitness-ul de: 4
# Solutia oyb2x23 are fitness-ul de: 4
# Solutia mi1c0f3 are fitness-ul de: 4
# Solutia msbe02e are fitness-ul de: 4
# Solutia dj92023 are fitness-ul de: 4
# Solutia mah20u3 are fitness-ul de: 4
# Solutia a4w2023 are fitness-ul de: 4
# Solutia mibf0xf are fitness-ul de: 4
# Solutia 3ib2a2h are fitness-ul de: 4
# Solutia qi32v23 are fitness-ul de: 4
# Solutia mi4212j are fitness-ul de: 4
# Solutia 9ib10x3 are fitness-ul de: 4
# Solutia ai82033 are fitness-ul de: 4
# Solutia m5bo0x3 are fitness-ul de: 4
# Solutia 2i0d023 are fitness-ul de: 4
# Solutia 6zb2003 are fitness-ul de: 4
# Solutia mxb2223 are fitness-ul de: 5
# Solutia civ2i23 are fitness-ul de: 4
# Solutia 1ib20sw are fitness-ul de: 4
# Solutia 0ib20qc are fitness-ul de: 4
# Solutia kub20q3 are fitness-ul de: 4
# Solutia eiu202k are fitness-ul de: 4
# Solutia uhb9023 are fitness-ul de: 4
# Solutia mpbg02p are fitness-ul de: 4
# Solutia cdb202h are fitness-ul de: 4
# Solutia mid102l are fitness-ul de: 4
# Solutia mix60m3 are fitness-ul de: 4
# Solutia qsx2023 are fitness-ul de: 4
# Solutia vibpr23 are fitness-ul de: 4
# Solutia mi12087 are fitness-ul de: 4
# Solutia 3ibi02l are fitness-ul de: 4
# Solutia mib2shq are fitness-ul de: 4
# Solutia mcu5023 are fitness-ul de: 4
# Solutia eir2n23 are fitness-ul de: 4
# Solutia mxz2s23 are fitness-ul de: 4
# Solutia chl2023 are fitness-ul de: 4
# Solutia zib80w3 are fitness-ul de: 4
# Solutia m6b8073 are fitness-ul de: 4
# Solutia mibs393 are fitness-ul de: 4
# Solutia zib2173 are fitness-ul de: 4
# Solutia m0bp02n are fitness-ul de: 4
# Solutia dib20b5 are fitness-ul de: 4
# Solutia mib0n2o are fitness-ul de: 4
# Solutia mzbz02s are fitness-ul de: 4
# Solutia oih2q23 are fitness-ul de: 4
# Solutia mib30tu are fitness-ul de: 4
# Solutia fib2e83 are fitness-ul de: 4
# Solutia mi1j022 are fitness-ul de: 4
# Solutia mi520cd are fitness-ul de: 4
# Solutia 1ibyv23 are fitness-ul de: 4
# Solutia mybj027 are fitness-ul de: 4
# Solutia mip8o23 are fitness-ul de: 4
# Solutia msb208l are fitness-ul de: 4
# Solutia 9it20q3 are fitness-ul de: 4
# Solutia j8b20m3 are fitness-ul de: 4
# Solutia zib2lq3 are fitness-ul de: 4
# Solutia mib2vkl are fitness-ul de: 4
# Solutia mibw82n are fitness-ul de: 4
# Solutia mibtt2v are fitness-ul de: 4
# Solutia siv202w are fitness-ul de: 4
# Solutia mibj0u2 are fitness-ul de: 4
# Solutia 2db202f are fitness-ul de: 4
# Solutia mt1p023 are fitness-ul de: 4
# Solutia n9b2t23 are fitness-ul de: 4
# Solutia mi62353 are fitness-ul de: 4
# Solutia 2ibo0j3 are fitness-ul de: 4
# Solutia bwb2v23 are fitness-ul de: 4
# Solutia wlh2023 are fitness-ul de: 4
# Solutia bib1028 are fitness-ul de: 4
# Solutia mibm727 are fitness-ul de: 4
# Solutia mis20ln are fitness-ul de: 4
# Solutia 2ub2043 are fitness-ul de: 4
# Solutia mib2sej are fitness-ul de: 4
# Solutia j4v2023 are fitness-ul de: 4
# Solutia mi520xi are fitness-ul de: 4
# Solutia mab25r3 are fitness-ul de: 4
# Solutia mobp0m3 are fitness-ul de: 4
# Solutia 8bb2q23 are fitness-ul de: 4
# Solutia mzbi063 are fitness-ul de: 4
# Solutia m3m2r23 are fitness-ul de: 4
# Solutia piv2523 are fitness-ul de: 4
# Solutia mibmsp3 are fitness-ul de: 4
# Solutia mif602w are fitness-ul de: 4
# Solutia mibj0te are fitness-ul de: 4
# Solutia mnb201w are fitness-ul de: 4
# Solutia mi2g022 are fitness-ul de: 4
# Solutia l3b202s are fitness-ul de: 4
# Solutia mivl523 are fitness-ul de: 4
# Solutia 4izn023 are fitness-ul de: 4
# Solutia 7ie202z are fitness-ul de: 4
# Solutia 9ib2u2s are fitness-ul de: 4
# Solutia mqo2m23 are fitness-ul de: 4
# Solutia mub50m3 are fitness-ul de: 4
# Solutia milr0g3 are fitness-ul de: 4
# Solutia oiu20c3 are fitness-ul de: 4
# Solutia m28202h are fitness-ul de: 4
# Solutia mi6l02b are fitness-ul de: 4
# Solutia ci220s3 are fitness-ul de: 4
# Solutia dqp2023 are fitness-ul de: 4
# Solutia 96b202w are fitness-ul de: 4
# Solutia 2ibs02m are fitness-ul de: 4
# Solutia meb5y23 are fitness-ul de: 4
# Solutia sib2032 are fitness-ul de: 4
# Solutia mi32cd3 are fitness-ul de: 4
# Solutia mob2e27 are fitness-ul de: 4
# Solutia 4i12623 are fitness-ul de: 4
# Solutia mibhe2g are fitness-ul de: 4
# Solutia lis2u23 are fitness-ul de: 4
# Solutia 1ibx02w are fitness-ul de: 4
# Solutia yhb9023 are fitness-ul de: 4
# Solutia m9b2gi3 are fitness-ul de: 4
# Solutia mibeif3 are fitness-ul de: 4
# Solutia dibz073 are fitness-ul de: 4
# Solutia wij202k are fitness-ul de: 4
# Solutia m42l023 are fitness-ul de: 4
# Solutia mib19m3 are fitness-ul de: 4
# Solutia mim2012 are fitness-ul de: 4
# Solutia tib2ib3 are fitness-ul de: 4
# Solutia sij2p23 are fitness-ul de: 4
# Solutia vib2xp3 are fitness-ul de: 4
# Solutia meb200n are fitness-ul de: 4
# Solutia mqbxx23 are fitness-ul de: 4
# Solutia m1mn023 are fitness-ul de: 4
# Solutia m70n023 are fitness-ul de: 4
# Solutia miz206x are fitness-ul de: 4
# Solutia 6rb2f23 are fitness-ul de: 4
# Solutia rgb202w are fitness-ul de: 4
# Solutia mx42q23 are fitness-ul de: 4
# Solutia 7kb202q are fitness-ul de: 4
# Solutia mjy2823 are fitness-ul de: 4
# Solutia bibi0e3 are fitness-ul de: 4
# Solutia 7fq2023 are fitness-ul de: 4
# Solutia mv7s023 are fitness-ul de: 4
# Solutia mnj0023 are fitness-ul de: 4
# Solutia mks202g are fitness-ul de: 4
# Solutia aib2p2r are fitness-ul de: 4
# Solutia xcb7023 are fitness-ul de: 4
# Solutia mibvy23 are fitness-ul de: 5
# Solutia 8nb2m23 are fitness-ul de: 4
# Solutia kip20w3 are fitness-ul de: 4
# Solutia mijvi23 are fitness-ul de: 4
# Solutia mmb20ea are fitness-ul de: 4
# Solutia mie30s3 are fitness-ul de: 4
# Solutia mca202d are fitness-ul de: 4
# Solutia mgbg02d are fitness-ul de: 4
# Solutia mlb90o3 are fitness-ul de: 4
# Solutia bib20ox are fitness-ul de: 4
# Solutia xibo0v3 are fitness-ul de: 4
# Solutia mubl0m3 are fitness-ul de: 4
# Solutia mij2wv3 are fitness-ul de: 4
# Solutia fma2023 are fitness-ul de: 4
# Solutia m8b25j3 are fitness-ul de: 4
# Solutia 3ix2523 are fitness-ul de: 4
# Solutia qi820n3 are fitness-ul de: 4
# Solutia dic8023 are fitness-ul de: 4
# Solutia mig2d2a are fitness-ul de: 4
# Solutia jvb20j3 are fitness-ul de: 4
# Solutia msb20oq are fitness-ul de: 4
# Solutia mib2bu4 are fitness-ul de: 4
# Solutia mik2j2r are fitness-ul de: 4
# Solutia mibo045 are fitness-ul de: 4
# Solutia mibce2c are fitness-ul de: 4
# Solutia gib20u2 are fitness-ul de: 4
# Solutia ms32z23 are fitness-ul de: 4
# Solutia fib282z are fitness-ul de: 4
# Solutia 4ib90z3 are fitness-ul de: 4
# Solutia mib5024 are fitness-ul de: 5
# Solutia lobv023 are fitness-ul de: 4
# Solutia mcbbz23 are fitness-ul de: 4
# Solutia uibxe23 are fitness-ul de: 4
# Solutia mias0n3 are fitness-ul de: 4
# Solutia mibwyo3 are fitness-ul de: 4
# Solutia m2b2x2b are fitness-ul de: 4
# Solutia mibube3 are fitness-ul de: 4
# Solutia mkbm0m3 are fitness-ul de: 4
# Solutia xibm024 are fitness-ul de: 4
# Solutia iizl023 are fitness-ul de: 4
# Solutia misq02r are fitness-ul de: 4
# Solutia meqa023 are fitness-ul de: 4
# Solutia iibwe23 are fitness-ul de: 4
# Solutia ki72s23 are fitness-ul de: 4
# Solutia aib20jv are fitness-ul de: 4
# Solutia qib2u2p are fitness-ul de: 4
# Solutia miiv0q3 are fitness-ul de: 4
# Solutia mibe0yl are fitness-ul de: 4
# Solutia m9b2i2z are fitness-ul de: 4
# Solutia mibg06c are fitness-ul de: 4
# Solutia aibmp23 are fitness-ul de: 4
# Solutia mib901i are fitness-ul de: 4
# Solutia mi4ix23 are fitness-ul de: 4
# Solutia iibn093 are fitness-ul de: 4
# Solutia 1ib2iq3 are fitness-ul de: 4
# Solutia mhb209x are fitness-ul de: 4
# Solutia kib4623 are fitness-ul de: 4
# Solutia mv6k023 are fitness-ul de: 4
# Solutia mibzn73 are fitness-ul de: 4
# Solutia mib2kfe are fitness-ul de: 4
# Solutia nib20lt are fitness-ul de: 4
# Solutia znb202v are fitness-ul de: 4
# Solutia vibcb23 are fitness-ul de: 4
# Solutia fi37023 are fitness-ul de: 4
# Solutia mmbsu23 are fitness-ul de: 4
# Solutia mibin22 are fitness-ul de: 4
# Solutia oilf023 are fitness-ul de: 4
# Solutia 9ib20om are fitness-ul de: 4
# Solutia m4p2y23 are fitness-ul de: 4
# Solutia m9b5923 are fitness-ul de: 4
# Elapsed time: 0:00:40.780692
# [8.209745e+06 1.642797e+06 1.405050e+05 6.735000e+03 2.150000e+02
#  3.000000e+00 0.000000e+00]

# %%
1000/10000000
# Out:
# 0.0001

# %% [markdown]
# ### E1 b.
# Implementați operatori de perturbație-modificare pentru o soluție în care:
# - Se schimbă un caracter, îm mod aleatoriu.
# - Caracterele sunt schimbate aleatoriu, cu o probabilitate specificată de utlizator.

# %%
def randomSampleIndex(sol, index2Change):
    new_char = random.choice(alphabet)
    return sol[:index2Change] + new_char + sol[index2Change+1:]

# %%
def mutateOneIndex(sol):
    index = random.randint(0, len(sol) - 1)
    new_char = random.choice(alphabet)
    return sol[:index] + new_char + sol[index+1:]

# %%
def mutateWithProb(sol, mutProb):
    new_sol = ""
    for char in sol:
       if random.random() < mutProb:
           new_char = random.choice(alphabet)
           new_sol += new_char
       else:
           new_sol += char
    return new_sol

# %% [markdown]
# ### E1 c.
#
# Implementați metodele 'hillClimber' și 'hillClimberSteepestAcent' / 'hillClimberSteepestDescent' prezentate la curs.
#
# - Care metodă și cu ce parametrizare are cele mai bune rezultate (pentru această problemă)?
# - Oare cum se explică diferența de performanță?
# - Pentru ce tipuri de probleme, rezultatul ar fi inversat (metoda mai slabă pe această problemă, să aibă o perfomranță mai bună)?

# %% [markdown]
# ### Răspuns
# 1. 'hillClimberSteepestAscent' ar trebui sa aiba o performanta decat 'hillClimber', deoarece aceasta alege mereu vecinul cu cea mai buna calitate.
# 2. Diferenaa de performanta se poate explica prin modul în care cele doua metode iau deciziile de a accepta sau respinge solutii noi. 'hillClimber' accepta orice vecin care are o calitate cel putin la fel de buna cu solutia curenta, ceea ce poate duce la blocarea într-un minim local. 'hillClimberSteepestAscent' alege întotdeauna cel mai bun vecin, permitandu-i sa iasa din minimul local si sa continue sa exploreze.
# 3. Daca problema ar fi una care are o multime de maxime locale, atunci ar fi posibil ca 'hillClimber' sa aiba o performanta mai buna deoarece poate fi suficient sa gaseasca un maxim local acceptabil si sa nu fie nevoie sa continue cautarea altor maxime.

# %%
def hillClimber(maxIterations = 10000000, mutProb = 0.1):
    # Generate a random initial solution and calculate its fitness
    current_sol = generateRandomSolution(target_length, alphabet)
    current_fitness = objFuncNumMatches(current_sol)
    best_fitness = current_fitness
    best_sol = current_sol
    
    # Main optimization loop
    for i in range(maxIterations):
        # mutate the current sol
        new_sol = mutateOneIndex(current_sol)
        new_fitness = objFuncNumMatches(new_sol)
        
        # update the current sol
        if new_fitness > current_fitness:
            current_sol = new_sol
            current_fitness = new_fitness
            
            # update the best solution
            if new_fitness > best_fitness:
                best_fitness = new_fitness
                best_sol = new_sol
    
    # Return the best solution found
    return best_sol

# %%
def hillClimberSteepestAscent(maxIterations = 10000000, mutProb = 0.1):
    current_sol = generateRandomSolution(target_length, alphabet)
    current_fitness = objFuncNumMatches(current_sol)
    best_fitness = current_fitness
    best_sol = current_sol
    
    for i in range(maxIterations):
        # generate all possible neighbor solutions
        neighbor_sols = [mutateOneIndex(current_sol, j) for j in range(target_length)]
        neighbor_fitnesses = [objFuncNumMatches(s) for s in neighbor_sols]
        
        # find the neighbor solution with the highest fitness
        max_index = neighbor_fitnesses.index(max(neighbor_fitnesses))
        
        # update the current solution
        if neighbor_fitnesses[max_index] > current_fitness:
            current_sol = neighbor_sols[max_index]
            current_fitness = neighbor_fitnesses[max_index]
            
            # update the best solution
            if current_fitness > best_fitness:
                best_fitness = current_fitness
                best_sol = current_sol
        
        # if there are no better neighbor solutions, stop the optimization loop
        else:
            break

    # Return the best solution found
    return best_sol

# %% [markdown]
# ## Exercițiul 2
#
# În acest exercițiu vom vizualiza traiectoria descrisă de metodele de căutare locală într-un spațiu de căutare 2D, observând efectul și interacțiunea strategiilor de [explorare și exploatare](https://towardsdatascience.com/intuition-exploration-vs-exploitation-c645a1d37c7a).
#
# Începem prin definirea unei metode ce afișează în 3D o funcție $z=f(x,y)$, cu posibilitatea setării [punctului de observare](https://matplotlib.org/mpl_toolkits/mplot3d/api.html#mpl_toolkits.mplot3d.axes3d.Axes3D.view_init).

# %%
import random
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import cm
from matplotlib.ticker import LinearLocator
from mpl_toolkits.mplot3d import Axes3D
import time

# %%
def plotSurface(X, Y, Z, titleLabel = '', el = 35, az = 40, width = 20, height = 6, zmin = 0, zmax = 1, transparency = 1, reuseFig = False):
  
  if reuseFig:
    fig = plt.gcf()
    ax = plt.gca()
  else:
    fig = plt.figure(figsize=(width, height))
    ax = Axes3D(fig)

  surf = ax.plot_surface(X, Y, Z, cmap=cm.binary, alpha = transparency, linewidth=0.5, edgecolors='gray')

  ax.set_zlim(zmin, zmax)
  fig.colorbar(surf, shrink=0.5, aspect=5)

  plt.xlabel('x')
  plt.ylabel('y')
  plt.title(titleLabel, fontsize=20)

  ax.elev = el
  ax.azim = az

  plt.show()

# %% [markdown]
# ### Funcție unimodală
#
# Ca prim exemplu, vom considera o funcție cu un singur maxim ([unimodală](https://en.wikipedia.org/wiki/Unimodality)). Metodele de îmbunătățire iterativă (hill-climbing) sunt foarte potrivite pentru optimizarea acestor funcții și vor converge ușor la maximul global.
#
# ![](https://upload.wikimedia.org/wikipedia/commons/0/05/Hill_climb.png)
#
# Fig. 1. Funcție unimodală $z = f(x, y) = e^{-(x^2 + y^2)}$

# %%
def objFuncUnimodal(x, y): # objective function, also called, fitness, energy etc.
    return np.exp(-(x*x+y*y))

# %% [markdown]
# Prezentarea funcției în 3D din diferite unghiuri

# %%
vectorizedUnimodal = np.vectorize(objFuncUnimodal)

X = np.arange(-2, 2, 0.05)
Y = np.arange(-2, 2, 0.05)
X, Y = np.meshgrid(X, Y)
Zu = vectorizedUnimodal(X,Y)

plotSurface(X, Y, Zu, '$z = e^{-(x^2 + y^2)}$', transparency=0.75)

# %%
# Same plot, another camera angle
plotSurface(X, Y, Zu, 'z = $e^{-(x^2 + y^2)}$', el=20, az = 120, transparency=0.85)

# %% [markdown]
# ### Funcție mutimodală
#
# În al doilea exemplu, considerăm o funcție cu două maxime locale ([multimodală](https://en.wikipedia.org/wiki/Multimodal_distribution)), dintre care numai unul este și maxim global. Metodele de îmbunătățire iterativă (hill-climbing) pot converge la maximul inferior dacă sunt pornite dintr-un punct ce se află departe de maximul global.
#
# ![](https://upload.wikimedia.org/wikipedia/commons/7/7e/Local_maximum.png)
#
# Fig. 2. Funcție multimodală $z = f(x, y) = e^{-(x^2 + y^2)} + 2e^{-((x-1.7)^2 + (y-1.7)^2)}$

# %%
def objFuncMultimodal(x, y):
    return np.exp(-(x*x+y*y)) + 2*np.exp(-( (x-1.7)**2 + (y-1.7)**2))

# %%
vectorizedMultimodal = np.vectorize(objFuncMultimodal)
X = np.arange(-2, 4, 0.05)
Y = np.arange(-2, 4, 0.05)
X, Y = np.meshgrid(X, Y)
Zm = vectorizedMultimodal(X,Y)

plotSurface(X, Y, Zm, '$z = e^{-(x^2 + y^2)} + 2e^{-((x-1.7)^2 + (y-1.7)^2)}$', el=50, az = 290, zmax = 2, transparency=0.85)

# %% [markdown]
# În următoarea celulă, afisăm traiectoria descrisă de o eșantionare uniform aleatorie din spațiul de căutare. Cum se poate observa, metoda sare aleatoriu dint-un punct în altul.

# %%
# generate random solutions and calculate and display their "fitness" (objective function value that we are maximizing)
xs = np.random.uniform(-2, 4, 20)
ys = np.random.uniform(-2, 4, 20)

zs = vectorizedMultimodal(xs, ys) + 0.1 # positive offset to draw slightly above surface

fig = plt.figure(figsize=(20, 5))
ax = Axes3D(fig)
ax.scatter(xs, ys, zs, c=zs, marker='o', s=range(10, 10*21, 10), cmap=cm.hot)

ax.plot(xs, ys, zs, c='r', linewidth=3, alpha=1)
ax.text(xs[0], ys[0], zs[0], 'start', color='blue', fontsize = 12)
ax.text(xs[-1], ys[-1], zs[-1], 'end', color='orange', fontsize = 18)

plotSurface(X, Y, Zm, '$z = e^{-(x^2 + y^2)} + 2e^{-((x-1.7)^2 + (y-1.7)^2)}$', el=60, az = 290, zmax = 2, transparency=0.25, reuseFig = True)

plt.show()

# %% [markdown]
# ### E2 a.
#
# Adaptați metodele `randomSearch`, `hillClimbing` și `hillClimbingSteepestAscent` pentru optimizarea unor funcții în două variabile, de forma $f(x,y)$, și vizualizați traiectoria descrisă pentru cele două funcții (unimodal și multimodal) prezentate.

# %% [markdown]
# ### E2 b.
#
# Alegeți două funcții mutimodale din cele folosite în competiția [Special Session & Competition on Real-Parameter Single Objective (Expensive) Optimization at IEEE Conference on Evolutionary Computation, CEC-2014, Beijing, PR-China, 6-11 July 2014](http://www5.zzu.edu.cn/cilab/info/1005/1013.htm) și analizați performanța strategiilor de îmbunătățirie iterativă pe acestea. De câte rulări și evaluări ale funcției obiective este nevoie pentru a localiza în mod fiabil optimul global? Cum afectează creșterea numărului de dimensiuni dificultatea acestor probleme de căutare?
#
#  Descrierea și prezentarea funcțiilor în detaliu:
#
#  https://en.wikipedia.org/wiki/Test_functions_for_optimization
#
#  și
#
#  http://www5.zzu.edu.cn/__local/A/69/BC/D3B5DFE94CD2574B38AD7CD1D12_C802DAFE_BC0C0.pdf
